# %% [markdown]
# # Exploratory Data Analysis
#
# In this notebook I carried out a quick EDA of the getaround pricing data to check :
# - Missing values
# - Target  and explanatory variables type and distribution
# - Target  and explanatory variables relationships
# - Outlier samples

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

# %% [markdown]
# ## Import data

# %%
df = pd.read_csv('../data/get_around_pricing_project_raw.csv').iloc[:, 1:]
print('Shape of princing data: There are {} samples and {} variables'.format(df.shape[0], df.shape[1]) )
df.head()
# Out:
# Shape of princing data: There are 4843 samples and 14 variables
#   model_key  mileage  engine_power    fuel paint_color     car_type  \
# 0   Citroën   140411           100  diesel       black  convertible
# 1   Citroën    13929           317  petrol        grey  convertible
# 2   Citroën   183297           120  diesel       white  convertible
# 3   Citroën   128035           135  diesel         red  convertible
# 4   Citroën    97097           160  diesel      silver  convertible
#
#    private_parking_available  has_gps  has_air_conditioning  automatic_car  \
# 0                       True     True                 False          False
# 1                       True     True                 False          False
# 2                      False    False                 False          False
# 3                       True     True                 False          False
# 4                       True     True                 False          False
#
#    has_getaround_connect  has_speed_regulator  winter_tires  \
# 0                   True                 True          True
# 1                  False                 True          True
# 2                   True                False          True
# 3                   True                 True          True
# 4                  False                 True          True
#
#    rental_price_per_day
# 0                   106
# 1                   264
# 2                   101
# 3                   158
# 4                   183

# %% [markdown]
# **Target Variable** : rental price per day

# %% [markdown]
# ## 1. Missing values

# %%
# Check data types and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4843 entries, 0 to 4842
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   model_key                  4843 non-null   object
#  1   mileage                    4843 non-null   int64
#  2   engine_power               4843 non-null   int64
#  3   fuel                       4843 non-null   object
#  4   paint_color                4843 non-null   object
#  5   car_type                   4843 non-null   object
#  6   private_parking_available  4843 non-null   bool
#  7   has_gps                    4843 non-null   bool
#  8   has_air_conditioning       4843 non-null   bool
#  9   automatic_car              4843 non-null   bool
#  10  has_getaround_connect      4843 non-null   bool
#  11  has_speed_regulator        4843 non-null   bool
#  12  winter_tires               4843 non-null   bool
#  13  rental_price_per_day       4843 non-null   int64
# dtypes: bool(7), int64(3), object(4)
# memory usage: 298.1+ KB

# %% [markdown]
# **There are no missing values**

# %% [markdown]
# ## 2. Variables distribution

# %%
# Describe variables
df.describe(include='all')
# Out:
#        model_key       mileage  engine_power    fuel paint_color car_type  \
# count       4843  4.843000e+03    4843.00000    4843        4843     4843
# unique        28           NaN           NaN       4          10        8
# top      Citroën           NaN           NaN  diesel       black   estate
# freq         969           NaN           NaN    4641        1633     1606
# mean         NaN  1.409628e+05     128.98823     NaN         NaN      NaN
# std          NaN  6.019674e+04      38.99336     NaN         NaN      NaN
# min          NaN -6.400000e+01       0.00000     NaN         NaN      NaN
# 25%          NaN  1.029135e+05     100.00000     NaN         NaN      NaN
# 50%          NaN  1.410800e+05     120.00000     NaN         NaN      NaN
# 75%          NaN  1.751955e+05     135.00000     NaN         NaN      NaN
# max          NaN  1.000376e+06     423.00000     NaN         NaN      NaN
#
#        private_parking_available has_gps has_air_conditioning automatic_car  \
# count                       4843    4843                 4843          4843
# unique                         2       2                    2             2
# top                         True    True                False         False
# freq                        2662    3839                 3865          3881
# mean                         NaN     NaN                  NaN           NaN
# std                          NaN     NaN                  NaN           NaN
# min                          NaN     NaN                  NaN           NaN
# 25%                          NaN     NaN                  NaN           NaN
# 50%                          NaN     NaN                  NaN           NaN
# 75%                          NaN     NaN                  NaN           NaN
# max                          NaN     NaN                  NaN           NaN
#
#        has_getaround_connect has_speed_regulator winter_tires  \
# count                   4843                4843         4843
# unique                     2                   2            2
# top                    False               False         True
# freq                    2613                3674         4514
# mean                     NaN                 NaN          NaN
# std                      NaN                 NaN          NaN
# min                      NaN                 NaN          NaN
# 25%                      NaN                 NaN          NaN
# 50%                      NaN                 NaN          NaN
# 75%                      NaN                 NaN          NaN
# max                      NaN                 NaN          NaN
#
#         rental_price_per_day
# count            4843.000000
# unique                   NaN
# top                      NaN
# freq                     NaN
# mean              121.214536
# std                33.568268
# min                10.000000
# 25%               104.000000
# 50%               119.000000
# 75%               136.000000
# max               422.000000

# %%
# Mileage outlier: there is a negative mileage value

df.mileage.sort_values()
# Out:
# 2938        -64
# 2409        476
# 4372        612
# 3935        706
# 3687       2399
#          ...
# 3198     405816
# 2829     439060
# 2350     477571
# 557      484615
# 3732    1000376
# Name: mileage, Length: 4843, dtype: int64

# %%
# Target variable has a really low price: 10 euros per day, which seems weird. Check this
# Since there are many other low values, keep them

df.rental_price_per_day.sort_values()
# Out:
# 565      10
# 630      10
# 879      10
# 2829     10
# 1832     10
#        ...
# 2938    274
# 4146    287
# 90      309
# 4684    378
# 4753    422
# Name: rental_price_per_day, Length: 4843, dtype: int64

# %%
# Check info for car with lowest price of rental per day
df.iloc[565,:]
# Out:
# model_key                    Citroën
# mileage                       179358
# engine_power                     120
# fuel                          diesel
# paint_color                    black
# car_type                      estate
# private_parking_available      False
# has_gps                         True
# has_air_conditioning           False
# automatic_car                  False
# has_getaround_connect          False
# has_speed_regulator            False
# winter_tires                    True
# rental_price_per_day              10
# Name: 565, dtype: object

# %%
# Compate to info for car with highest price of rental per day
df.iloc[4753,:]
# Out:
# model_key                       BMW
# mileage                       72515
# engine_power                    135
# fuel                         diesel
# paint_color                    blue
# car_type                        suv
# private_parking_available     False
# has_gps                       False
# has_air_conditioning           True
# automatic_car                 False
# has_getaround_connect         False
# has_speed_regulator           False
# winter_tires                  False
# rental_price_per_day            422
# Name: 4753, dtype: object

# %% [markdown]
# ## 3. Variable relationships

# %%
corrMatrix = df.corr()
display (corrMatrix)
# Out:
#                             mileage  engine_power  private_parking_available  \
# mileage                    1.000000     -0.050116                   0.065258
# engine_power              -0.050116      1.000000                   0.327213
# private_parking_available  0.065258      0.327213                   1.000000
# has_gps                    0.009695      0.201202                   0.305965
# has_air_conditioning       0.003621      0.312789                   0.254764
# automatic_car             -0.052857      0.447769                   0.230125
# has_getaround_connect      0.046706      0.341004                   0.278320
# has_speed_regulator       -0.029626      0.232058                   0.134274
# winter_tires               0.154827      0.008905                   0.243831
# rental_price_per_day      -0.448912      0.625645                   0.281358
#
#                             has_gps  has_air_conditioning  automatic_car  \
# mileage                    0.009695              0.003621      -0.052857
# engine_power               0.201202              0.312789       0.447769
# private_parking_available  0.305965              0.254764       0.230125
# has_gps                    1.000000              0.150669       0.149922
# has_air_conditioning       0.150669              1.000000       0.199477
# automatic_car              0.149922              0.199477       1.000000
# has_getaround_connect      0.285422              0.198823       0.250277
# has_speed_regulator        0.136106              0.144153       0.153347
# winter_tires               0.370019              0.062218       0.126184
# rental_price_per_day       0.310889              0.245386       0.419761
#
#                            has_getaround_connect  has_speed_regulator  \
# mileage                                 0.046706            -0.029626
# engine_power                            0.341004             0.232058
# private_parking_available               0.278320             0.134274
# has_gps                                 0.285422             0.136106
# has_air_conditioning                    0.198823             0.144153
# automatic_car                           0.250277             0.153347
# has_getaround_connect                   1.000000             0.257245
# has_speed_regulator                     0.257245             1.000000
# winter_tires                            0.203305             0.129273
# rental_price_per_day                    0.318486             0.227547
#
#                            winter_tires  rental_price_per_day
# mileage                        0.154827             -0.448912
# engine_power                   0.008905              0.625645
# private_parking_available      0.243831              0.281358
# has_gps                        0.370019              0.310889
# has_air_conditioning           0.062218              0.245386
# automatic_car                  0.126184              0.419761
# has_getaround_connect          0.203305              0.318486
# has_speed_regulator            0.129273              0.227547
# winter_tires                   1.000000              0.018277
# rental_price_per_day           0.018277              1.000000

# %% [markdown]
# ## 4. Dataset summary
#
# - There are **4843 samples** and **14 variables**
#
#  - The **target variable** is the **rental pricer per day**
# - There are **no missing values**
# - There is **one outlier sample** with a **negative mileage**
# - Variable types:
#   - **Categorical** (11):
#     - Boolean (7) : *private_parking_available, has_gps, has_air_conditioning, automatic_car, has_getaround_connect, has_speed_regulator, winter_tires*
#     - Str (4): *model_key, fuel, paint_color, car_type*
#   <br>
# - **Numerical** (3): *mileage, engine power*
# - Variable relationships:
#   - **No collinearity** found
#   - A **slight** positive **correlation** between **target** variable and **engine_power** (Pearson corr of 0.63)

# %%
# Export clean dataframe without outlier
df_clean = df.drop(2938)
print(df.shape)
print(df_clean.shape)

df_clean.to_csv('../data/get_around_pricing_project_clean.csv', index=False)
# Out:
# (4843, 14)
# (4842, 14)
